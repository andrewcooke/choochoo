# %%
from ch2.data import data
d = data('-v', '0')
stats = d.statistic_names('%HR%')
print(stats[['name', 'units']])
# Out:
#                          name    units
# 0           Avg/Month Rest HR      bpm
# 1            Avg/Year Rest HR      bpm
# 2           Cnt/Month Rest HR  entries
# 3            Cnt/Year Rest HR  entries
# 4                        FTHR      bpm
# 5                        FTHR      bpm
# 6              Max Med HR 10m      bpm
# 7             Max Med HR 120m      bpm
# 8              Max Med HR 15m      bpm
# 9             Max Med HR 180m      bpm
# 10             Max Med HR 20m      bpm
# 11             Max Med HR 30m      bpm
# 12              Max Med HR 5m      bpm
# 13             Max Med HR 60m      bpm
# 14             Max Med HR 90m      bpm
# 15   Max/Month Max Med HR 10m      bpm
# 16  Max/Month Max Med HR 120m      bpm
# 17   Max/Month Max Med HR 15m      bpm
# 18  Max/Month Max Med HR 180m      bpm
# 19   Max/Month Max Med HR 20m      bpm
# 20   Max/Month Max Med HR 30m      bpm
# 21    Max/Month Max Med HR 5m      bpm
# 22   Max/Month Max Med HR 60m      bpm
# ...

# %%
from bokeh.plotting import figure, output_notebook, show
from ch2.data import bokeh_boxplot
data = d.statistic_quartiles('Max Med HR 30m')
output_notebook()
f = figure(plot_width=800, plot_height=250, x_axis_type='datetime', title='Max Med HR 30 min')
bokeh_boxplot(f, data['Max Med HR 30m'])
f.xaxis.axis_label = 'Date'
f.yaxis.axis_label = 'Heart rate / bpm'
show(f)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="47c27f9f-6dbd-4f2f-a5a9-cc6bd010bb51"></div>
