# %%
from ch2.data import data
d = data()
d.statistic_names('Daily Steps')
sj = d.statistic_journals('Daily Steps', start='2018-09-15')
# Out:
#     INFO: Using database at /home/andrew/.ch2/database.sqll

# %%
import datetime as dt
from bokeh.plotting import figure, output_notebook, show
from ch2.lib.date import to_time
def plot(data, key):
    output_notebook()
    f = figure(plot_width=800, plot_height=250, x_axis_type='datetime', title='Steps')
    f.vbar(x=data.index, width=dt.timedelta(hours=20), top=data[key])
    f.xaxis.axis_label = 'Date'
    f.yaxis.axis_label = 'Steps / day'
    show(f)
plot(sj[to_time('2018-08-01'):], 'Daily Steps')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1645">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="76ff2ac0-bf9a-4f9a-a08c-84ee9f9421f8"></div>

# %%
sj['m5'] = sj['Daily Steps'].rolling(5).mean(center=True)
plot(sj[to_time('2018-08-01'):], 'm5')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1891">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="21047883-e536-43e2-9361-3ac2657366f8"></div>

# %%
output_notebook()
sj['m10'] = sj['Daily Steps'].rolling(10).mean(center=True)
data = sj[to_time('2018-08-20'):]
f = figure(plot_width=800, plot_height=250, x_axis_type='datetime', title='Steps')
f.vbar(x=data.index, width=dt.timedelta(hours=20), top=data['Daily Steps'])
f.line(x=data.index, y=data['m5'], color='orange', line_width=2, line_dash='dashed')
f.line(x=data.index, y=data['m10'], color='firebrick', line_width=3)
f.xaxis.axis_label = 'Date'
f.yaxis.axis_label = 'Steps / day'
show(f)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2157">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="aa2fce01-518a-4768-8736-f0593769fbcc"></div>
