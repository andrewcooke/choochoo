# %%
from collections import defaultdict
import pandas as pd
data = [(-7861174.272373196, -3950566.7266961834, 0),
(-7861229.205504273, -3950558.854978553, 23.7),
(-7861174.272373196, -3950566.7266961834, 0),
(-7861173.812967021, -3950566.9222152582, 0.3),
(-7862874.120997609, -3952059.1730653215, 0),
(-7862849.785379299, -3952053.212046412, 11.5),
(-7862835.184955569, -3952050.432061973, 18.1),
(-7862845.157356102, -3952066.9745473615, 13.9),
(-7861174.272373196, -3950566.7266961834, 0),
(-7861235.9633567985, -3950557.9483339125, 26.6)]
temp = defaultdict(list)
for x, y, d in data:
    temp['x'].append(x)
    temp['y'].append(y)
    temp['d'].append(d)
df = pd.DataFrame(temp)
print(df)
# Out:
#               x             y     d
# 0 -7.861174e+06 -3.950567e+06   0.0
# 1 -7.861229e+06 -3.950559e+06  23.7
# 2 -7.861174e+06 -3.950567e+06   0.0
# 3 -7.861174e+06 -3.950567e+06   0.3
# 4 -7.862874e+06 -3.952059e+06   0.0
# 5 -7.862850e+06 -3.952053e+06  11.5
# 6 -7.862835e+06 -3.952050e+06  18.1
# 7 -7.862845e+06 -3.952067e+06  13.9
# 8 -7.861174e+06 -3.950567e+06   0.0
# 9 -7.861236e+06 -3.950558e+06  26.6

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import LabelSet
from bokeh.models.sources import ColumnDataSource
from bokeh.tile_providers import CARTODBPOSITRON, STAMEN_TERRAIN, STAMEN_TONER
output_notebook()
f = figure(plot_width=800, plot_height=800, x_axis_type='mercator', y_axis_type='mercator')
f.circle(x='x', y='y', source=df)
f.add_tile(CARTODBPOSITRON)
f.add_layout(LabelSet(x='x', y='y', text='d', x_offset=5, y_offset=5, level='glyph', source=ColumnDataSource(df), render_mode='canvas'))
show(f)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1276">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="167bf2ec-118a-487b-8c32-461282608d2c"></div>
