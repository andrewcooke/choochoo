# %%
from ch2.data import *
from ch2.squeal import *

s = session('-v4')
st = activity_statistics(s, 'Raw Elevation', 'Elevation',
                         'Altitude', 'Spherical Mercator X', 'Spherical Mercator Y', 'Distance',
                         time='2018-03-04 14:00')
st.describe()
# Out:
#     INFO: Using database at /home/andrew/.ch2/database.sqlo
#     INFO: Using activity_journal_id=60864
#  WARNING: Missing Altitude at 2018-03-04 10:16:33+00:00 (single warning)
#  WARNING: Missing Raw Elevation at 2018-03-04 10:16:33+00:00 (single warning)
#  WARNING: Missing Spherical Mercator X at 2018-03-04 10:16:33+00:00 (single warning)
#  WARNING: Missing Spherical Mercator Y at 2018-03-04 10:16:33+00:00 (single warning)
#  WARNING: Missing Elevation at 2018-03-04 10:18:41+00:00 (single warning)
#             Distance    Elevation     Altitude  Raw Elevation  \
# count    2933.000000  2807.000000  2886.000000    2885.000000
# mean    52424.331323   580.725424   570.093971     582.754885
# std     29499.017849   147.581378   151.907694     149.546199
# min         0.000000   400.316122   378.200000     400.489290
# 25%     29534.110000   478.944009   464.800000     479.388722
# 50%     52038.000000   520.540756   507.600000     522.489819
# ...

# %%
from bokeh.plotting import figure, output_notebook, show

output_notebook()
f = figure(plot_width=800, plot_height=250)

f.line(x='Distance', y='Altitude', source=st, color='black', line_width=2)
f.line(x='Distance', y='Raw Elevation', source=st, color='red', line_width=2)
f.line(x='Distance', y='Elevation', source=st, color='blue', line_dash='dotted', line_width=2)
f.xaxis.axis_label = 'Distance'
f.yaxis.axis_label = 'Elevation / m'
show(f)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5b4c1f12-ed73-47ca-b103-d7307a84ed56"></div>

# %%
from bokeh.layouts import row
from bokeh.models import HoverTool
from bokeh.tile_providers import CARTODBPOSITRON, STAMEN_TERRAIN, STAMEN_TONER

st2 = st.loc[(st['Distance'] > 55000) & (st['Distance'] < 59000)]
st2.describe()

ht = HoverTool(tooltips={'Distance': '@{Distance}'})

f = figure(plot_width=400, plot_height=400)
f.line(x='Distance', y='Altitude', source=st2, color='black', line_width=2)
f.line(x='Distance', y='Raw Elevation', source=st2, color='red', line_width=2)
f.line(x='Distance', y='Elevation', source=st2, color='red', line_dash='dotted', line_width=2)
f.xaxis.axis_label = 'Distance'
f.yaxis.axis_label = 'Elevation / m'

g = figure(plot_width=400, plot_height=400, x_axis_type='mercator', y_axis_type='mercator', tools=[ht])
g.line(x='Spherical Mercator X', y='Spherical Mercator Y', source=st2)
g.add_tile(CARTODBPOSITRON)

show(row(f, g))
# Out:
#   <div class="bk-root" id="bfc80ded-adee-472d-be77-67c94e2b710e"></div>

# %%
st3 = activity_statistics(s, 'Raw Elevation 0', 'Raw Elevation 5', 'Raw Elevation 7', 'Raw Elevation 10',
                         'Elevation 0', 'Elevation 5', 'Elevation 7', 'Elevation 10',
                         'Altitude', 'Spherical Mercator X', 'Spherical Mercator Y', 'Distance',
                         time='2019-01-31 14:00')

f = figure(plot_width=800, plot_height=250)
f.line(x='Distance', y='Altitude', source=st3, color='black', line_width=2)
f.line(x='Distance', y='Raw Elevation', source=st3, color='red', line_width=2)
f.line(x='Distance', y='Elevation', source=st3, color='red', line_dash='dotted', line_width=2)
f.xaxis.axis_label = 'Distance'
f.yaxis.axis_label = 'Elevation / m'
show(f)
# Out:
#     INFO: Using activity_journal_id=60278
#  WARNING: Missing Altitude at 2019-01-31 13:40:30+00:00 (single warning)
#    ERROR: E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Elevation [renderer: GlyphRenderer(id='1502', ...)]
#    ERROR: E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Raw Elevation [renderer: GlyphRenderer(id='1496', ...)]
#   <div class="bk-root" id="8762b856-aa51-44cd-95bf-91890867a3ca"></div>
