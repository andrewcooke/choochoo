# %%
from ch2.data import *
from ch2.squeal import *
s = session('-v 4')
for n in s.query(StatisticName).filter(StatisticName.name.like('Active %')).all():
    print(n.name)
d = df(s.query(StatisticJournalFloat).join(StatisticName).filter(StatisticName.name == 'Active Distance'))
print(d.describe())
# Out:
#     INFO: Using database at /home/andrew/.ch2/database.sqln
# Active Distance
# Active Time
# Active Speed
#                  id            id   type  statistic_name_id     source_id  \
# count  3.340000e+02  3.340000e+02  334.0              334.0    334.000000
# mean   5.141543e+07  5.141543e+07    2.0              250.0  35582.961078
# std    1.913712e+03  1.913712e+03    0.0                0.0    101.652185
# min    5.141237e+07  5.141237e+07    2.0              250.0  35408.000000
# 25%    5.141371e+07  5.141371e+07    2.0              250.0  35495.250000
# 50%    5.141533e+07  5.141533e+07    2.0              250.0  35582.500000
# 75%    5.141705e+07  5.141705e+07    2.0              250.0  35671.750000
# max    5.141879e+07  5.141879e+07    2.0              250.0  35757.000000
#
#                value
# count     334.000000
# mean    51048.716946
# std     40239.220685
# min      2890.650000
# 25%     17800.095000
# 50%     38604.960000
# 75%     77545.947500
# ...

# %%
from bokeh.plotting import figure, output_notebook, show
output_notebook()
f = figure(plot_width=800, plot_height=250, x_axis_type='datetime', title='Distance for all rides')
f.circle(x=d.time, y=d.value / 1000)
f.xaxis.axis_label = 'Date'
f.yaxis.axis_label = 'Distance / km'
show(f)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1294">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="45c29bd0-5b30-495b-a36e-e86f7a63f3ec"></div>
