# %%
from ch2.data import *
from ch2.squeal import *

s = session('-v4')
st = activity_statistics(s, 'Elevation', 'Altitude', time='2018-03-04 14:00')
st.describe()
# Out:
#     INFO: Using database at /home/andrew/.ch2/database.sqln
#     INFO: Using activity_journal_id=56287
#  WARNING: Missing Elevation at 2018-03-04 10:19:02+00:00 (single warning)
#           Altitude    Elevation
# count  2886.000000  2885.000000
# mean    570.093971   582.754885
# std     151.907694   149.546199
# min     378.200000   400.489290
# 25%     464.800000   479.388722
# 50%     507.600000   522.489819
# 75%     605.800000   617.627825
# max     982.800000  1001.733117

# %%
from bokeh.plotting import figure, output_notebook, show

output_notebook()
f = figure(plot_width=800, plot_height=250, x_axis_type='datetime')
f.line(x=st.index, y=st['Elevation'], color='black')
f.line(x=st.index, y=st['Altitude'], color='red')
f.xaxis.axis_label = 'Date'
f.yaxis.axis_label = 'Elevation / m'
show(f)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="eb372502-96a2-4384-85b5-92a6e5078e27" data-root-id="1002"></div>
