# %%
from ch2.data import data, statistic_gui
statistic_gui(data('-v', '0'))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:41471/autoload.js?bokeh-autoload-element=1002&bokeh-absolute-url=http://localhost:41471&resources=none" id="1002"></script>
# INFO:sqlalchemy.engine.base.Engine:SELECT statistic_name.id AS statistic_name_id, statistic_name.name AS statistic_name_name, statistic_name.description AS statistic_name_description, statistic_name.units AS statistic_name_units, statistic_name.summary AS statistic_name_summary, statistic_name.owner AS statistic_name_owner, statistic_name."constraint" AS statistic_name_constraint
# FROM statistic_name
# WHERE statistic_name.name LIKE ?
# INFO:sqlalchemy.engine.base.Engine:('FTHR',)
# ...
