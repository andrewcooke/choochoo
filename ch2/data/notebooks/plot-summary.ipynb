# %%
from ch2.data import data
ch2 = data('-v', '0')
cycling = ch2.activity('Cycling')
stats = cycling.statistics('.*')
for s in stats:
    print(s.name, ':', s.units)
# Out:
# Max med HR over 120m : bpm
# Median 75km time : s
# Max med HR over 15m : bpm
# Max med HR over 180m : bpm
# Percent in Z1 : %
# Max med HR over 20m : bpm
# Percent in Z2 : %
# Max med HR over 30m : bpm
# Max med HR over 5m : bpm
# Percent in Z3 : %
# Max med HR over 60m : bpm
# Percent in Z4 : %
# Max med HR over 90m : bpm
# Median 100km time : s
# Percent in Z5 : %
# Median 10km time : s
# Time in Z1 : s
# Median 150km time : s
# Median 15km time : s
# Time in Z2 : s
# Median 20km time : s
# Time in Z3 : s
# Median 25km time : s
# Active distance : m
# Time in Z4 : s
# Active speed : km/h
# Median 50km time : s
# Time in Z5 : s
# Active time : s
# Median 5km time : s
# Max med HR over 10m : bpm

# %%
from bokeh.plotting import figure, output_notebook, show
from ch2.data import bokeh_boxplot

data = cycling.summary_statistics('Max med HR over 30m')

output_notebook()
f = figure(plot_width=800, plot_height=250, x_axis_type='datetime', title='Max median HR over 30 min')
bokeh_boxplot(f, data['Max med HR over 30m'])
f.xaxis.axis_label = 'Date'
f.yaxis.axis_label = 'Heart rate / bpm'
show(f)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="deed3a40-042c-4a12-b745-492af9dfbb80">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9ceb71ee-25ed-4e43-aac6-5aec82bd04d0"></div>
