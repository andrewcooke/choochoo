# %%
from ch2.data import data
from bokeh.plotting import figure, output_notebook, show
d = data('-v', '0')
print(d.statistics('%HR%'))
data = d.statistic_journals('Rest HR')
print(data)
output_notebook()
f = figure(plot_width=800, plot_height=250, x_axis_type='datetime', title='Rest HR')
f.circle(x=data.index, y=data['Rest HR'])
f.xaxis.axis_label = 'Date'
f.yaxis.axis_label = 'Heart Rate / bpm'
show(f)
# Out:
#                         name  \
# 0                       FTHR
# 1                       FTHR
# 2    Max Max Med HR over 10m
# 3   Max Max Med HR over 120m
# 4    Max Max Med HR over 15m
# 5   Max Max Med HR over 180m
# 6    Max Max Med HR over 20m
# 7    Max Max Med HR over 30m
# 8     Max Max Med HR over 5m
# 9    Max Max Med HR over 60m
# 10   Max Max Med HR over 90m
# 11       Max Med HR over 10m
# 12      Max Med HR over 120m
# 13       Max Med HR over 15m
# 14      Max Med HR over 180m
# 15       Max Med HR over 20m
# 16       Max Med HR over 30m
# 17        Max Med HR over 5m
# 18       Max Med HR over 60m
# 19       Max Med HR over 90m
# 20                   Rest HR
#
#                                           description units summary  \
# 0   Heart rate at functional threshold (cycling).\...   bpm    None
# 1   Heart rate at functional threshold (running).\...   bpm    None
# 2                                                None   bpm    None
# 3                                                None   bpm    None
# 4                                                None   bpm    None
# 5                                                None   bpm    None
# 6                                                None   bpm    None
# 7                                                None   bpm    None
# 8                                                None   bpm    None
# 9                                                None   bpm    None
# 10                                               None   bpm    None
# 11                                               None   bpm     max
# 12                                               None   bpm     max
# 13                                               None   bpm     max
# 14                                               None   bpm     max
# 15                                               None   bpm     max
# 16                                               None   bpm     max
# 17                                               None   bpm     max
# 18                                               None   bpm     max
# 19                                               None   bpm     max
# 20                                               None    kg   [avg]
#
#                                                owner  constraint  count
# 0      <class 'ch2.squeal.tables.constant.Constant'>         1.0      1
# 1      <class 'ch2.squeal.tables.constant.Constant'>         2.0      0
# 2     <class 'ch2.stoats.summary.SummaryStatistics'>         NaN     26
# 3     <class 'ch2.stoats.summary.SummaryStatistics'>         NaN     14
# 4     <class 'ch2.stoats.summary.SummaryStatistics'>         NaN     26
# 5     <class 'ch2.stoats.summary.SummaryStatistics'>         NaN      5
# 6     <class 'ch2.stoats.summary.SummaryStatistics'>         NaN     25
# 7     <class 'ch2.stoats.summary.SummaryStatistics'>         NaN     24
# 8     <class 'ch2.stoats.summary.SummaryStatistics'>         NaN     26
# 9     <class 'ch2.stoats.summary.SummaryStatistics'>         NaN     23
# 10    <class 'ch2.stoats.summary.SummaryStatistics'>         NaN     22
# 11  <class 'ch2.stoats.activity.ActivityStatistics'>         1.0    216
# 12  <class 'ch2.stoats.activity.ActivityStatistics'>         1.0     20
# 13  <class 'ch2.stoats.activity.ActivityStatistics'>         1.0    196
# 14  <class 'ch2.stoats.activity.ActivityStatistics'>         1.0      5
# 15  <class 'ch2.stoats.activity.ActivityStatistics'>         1.0    177
# 16  <class 'ch2.stoats.activity.ActivityStatistics'>         1.0    133
# 17  <class 'ch2.stoats.activity.ActivityStatistics'>         1.0    220
# 18  <class 'ch2.stoats.activity.ActivityStatistics'>         1.0     62
# 19  <class 'ch2.stoats.activity.ActivityStatistics'>         1.0     40
# 20           <class 'ch2.squeal.tables.topic.Topic'>         NaN      0
# Empty DataFrame
# Columns: []
# Index: []
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="401f10b7-563b-4ca4-bc5f-90c8acd3d562">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/project/ch2/choochoo/env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rest HR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-283b278d6b8d> in <module>
#       7 output_notebook()
#       8 f = figure(plot_width=800, plot_height=250, x_axis_type='datetime', title='Rest HR')
# ----> 9 f.circle(x=data.index, y=data['Rest HR'])
#      10 f.xaxis.axis_label = 'Date'
#      11 f.yaxis.axis_label = 'Heart Rate / bpm'
#
# ~/project/ch2/choochoo/env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/project/ch2/choochoo/env/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/project/ch2/choochoo/env/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/project/ch2/choochoo/env/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/project/ch2/choochoo/env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rest HR'
